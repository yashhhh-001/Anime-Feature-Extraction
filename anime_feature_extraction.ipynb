# %% [markdown]
# <h1 align="center">🎌 Anime Feature Extraction 🎌</h1>

# %% [markdown]
# <h1 align="center">Introduction</h1>

# %% [markdown]
# This project focuses on extracting meaningful features from an anime dataset to prepare it for machine learning tasks such as recommendation systems or classification.
#
# The objective is to transform raw categorical, textual, and numerical data into structured, ML-ready features using Python.

# %% [markdown]
# ### Importing Tools

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sn

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

# %% [markdown]
# ### Reading Data

# %%
data=pd.read_csv('anime.csv')
data.head()
# Out:
#    Rank  \
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5
#
#                                                                                                                Title  \
# 0     Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview
# 1                                                         Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members
# 2                                             Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members
# 3                                                              Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 members
# 4  Shingeki no Kyojin Season 3 Part 2TV (10 eps)Apr 2019 - Jul 20192,146,679 membersManga StoreVolume 1€10.99Preview
#
#    Score
# 0   9.10
# 1   9.07
# 2   9.06
# 3   9.06
# 4   9.05

# %% [markdown]
# ### Info of given data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    50 non-null     int64
#  1   Title   50 non-null     object
#  2   Score   50 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# ### Extracting Episode Count

# %%
def extract_ep(title):
    str(title)
    ep=""
    for i in range(len(title)):
        if(title[i]=='('):
            i+=1
            while(title[i]!=')'):
                ep+=title[i]
                i+=1
            break
        else: continue
    return int(ep.split(' ')[0])

# %%
data['Episode_Count']=data['Title'].apply(extract_ep)

# %%
data.head(3)
# Out:
#    Rank  \
# 0     1
# 1     2
# 2     3
#
#                                                                                                             Title  \
# 0  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview
# 1                                                      Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members
# 2                                          Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members
#
#    Score  Episode_Count
# 0   9.10             64
# 1   9.07             24
# 2   9.06             13

# %%
data.head(10)['Title']
# Out:
# 0       Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview
# 1                                                           Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members
# 2                                               Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members
# 3                                                                Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 members
# 4    Shingeki no Kyojin Season 3 Part 2TV (10 eps)Apr 2019 - Jul 20192,146,679 membersManga StoreVolume 1€10.99Preview
# 5                                                                Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 members
# 6                                                    Gintama: The FinalMovie (1 eps)Jan 2021 - Jan 2021137,208 members
# 7                                                     Hunter x Hunter TV (148 eps)Oct 2011 - Sep 20142,701,154 members
# 8                              Kaguya-sama wa Kokurasetai: Ultra RomanticTV (13 eps)Apr 2022 - Jun 2022851,445 members
# 9                                                     Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2013313,446 members
# Name: Title, dtype: object

# %% [markdown]
# ### Extracting Time Stamp

# %%
def extract_TS(title):
    TS=""
    for i in range(len(title)):
        if(title[i]==')'):
            i+=1
            while(title[i]!=','):
                if(len(TS)<19):
                    TS+=title[i]
                i+=1
            break;
        else: continue
    return TS;

# %%
data['Time_Stamp']=data['Title'].apply(extract_TS)

# %%
data.head(4)
# Out:
#    Rank  \
# 0     1
# 1     2
# 2     3
# 3     4
#
#                                                                                                             Title  \
# 0  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview
# 1                                                      Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members
# 2                                          Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members
# 3                                                           Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 members
#
#    Score  Episode_Count           Time_Stamp
# 0   9.10             64  Apr 2009 - Jul 2010
# 1   9.07             24  Apr 2011 - Sep 2011
# 2   9.06             13  Oct 2022 - Dec 2022
# 3   9.06             51  Apr 2015 - Mar 2016

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           50 non-null     int64
#  1   Title          50 non-null     object
#  2   Score          50 non-null     float64
#  3   Episode_Count  50 non-null     int64
#  4   Time_Stamp     50 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.1+ KB

# %%
data['Time_Stamp']=data['Time_Stamp'].astype(str)

# %% [markdown]
# ### Time Stamp -> Start & End

# %%
data["start"]=data['Time_Stamp'].str.split('-').str[0]
data["End"]=data['Time_Stamp'].str.split('-').str[1]

# %%
data.head()
# Out:
#    Rank  \
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5
#
#                                                                                                                Title  \
# 0     Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview
# 1                                                         Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members
# 2                                             Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members
# 3                                                              Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 members
# 4  Shingeki no Kyojin Season 3 Part 2TV (10 eps)Apr 2019 - Jul 20192,146,679 membersManga StoreVolume 1€10.99Preview
#
#    Score  Episode_Count           Time_Stamp      start        End
# 0   9.10             64  Apr 2009 - Jul 2010  Apr 2009    Jul 2010
# 1   9.07             24  Apr 2011 - Sep 2011  Apr 2011    Sep 2011
# 2   9.06             13  Oct 2022 - Dec 2022  Oct 2022    Dec 2022
# 3   9.06             51  Apr 2015 - Mar 2016  Apr 2015    Mar 2016
# 4   9.05             10  Apr 2019 - Jul 2019  Apr 2019    Jul 2019

# %% [markdown]
# ### Deletion of Intermediate Result

# %%
data.drop('Time_Stamp',axis=1,inplace=True)

# %%
data.head(3)
# Out:
#    Rank  \
# 0     1
# 1     2
# 2     3
#
#                                                                                                             Title  \
# 0  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview
# 1                                                      Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members
# 2                                          Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members
#
#    Score  Episode_Count      start        End
# 0   9.10             64  Apr 2009    Jul 2010
# 1   9.07             24  Apr 2011    Sep 2011
# 2   9.06             13  Oct 2022    Dec 2022

# %% [markdown]
# ### Extracting Months

# %%
data['start_dt'] = pd.to_datetime(data['start'].str.strip(),format='%b %Y')

data['end_dt'] = pd.to_datetime(data['End'].str.strip(),format='%b %Y')

data['months'] = (
    (data['end_dt'].dt.year - data['start_dt'].dt.year) * 12 +
    (data['end_dt'].dt.month - data['start_dt'].dt.month)
)

# %%
data.drop(['start_dt','end_dt'],axis=1,inplace=True)

# %%
data.head(2)
# Out:
#    Rank  \
# 0     1
# 1     2
#
#                                                                                                             Title  \
# 0  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview
# 1                                                      Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members
#
#    Score  Episode_Count      start        End  months
# 0   9.10             64  Apr 2009    Jul 2010      15
# 1   9.07             24  Apr 2011    Sep 2011       5

# %% [markdown]
# ### Longest Running Show in Data

# %%
data[data['months']==data['months'].max()][['Title','Score']]
# Out:
#                                                                   Title  Score
# 11  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Mar 1997309,193 members   9.02

# %% [markdown]
# ### Extracting Name + Type

# %%
def extract_name(title):
    name=""
    for i in range(len(title)):
        while(title[i]!='('):
            name+=title[i]
            i+=1
        break
    return name

# %%
data["Name"]=data['Title'].apply(extract_name)

# %%
data.head(3)
# Out:
#    Rank  \
# 0     1
# 1     2
# 2     3
#
#                                                                                                             Title  \
# 0  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview
# 1                                                      Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members
# 2                                          Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members
#
#    Score  Episode_Count      start        End  months  \
# 0   9.10             64  Apr 2009    Jul 2010      15
# 1   9.07             24  Apr 2011    Sep 2011       5
# 2   9.06             13  Oct 2022    Dec 2022       2
#
#                                   Name
# 0  Fullmetal Alchemist: BrotherhoodTV
# 1                       Steins;GateTV
# 2         Bleach: Sennen Kessen-henTV

# %%
print(data.loc[49]["Name"])
# Out:
# Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-henOVA

# %%
data["Name"].astype(str)
# Out:
# 0                              Fullmetal Alchemist: BrotherhoodTV
# 1                                                   Steins;GateTV
# 2                                     Bleach: Sennen Kessen-henTV
# 3                                                      Gintama°TV
# 4                            Shingeki no Kyojin Season 3 Part 2TV
# 5                                                      Gintama'TV
# 6                                         Gintama: The FinalMovie
# 7                                              Hunter x Hunter TV
# 8                    Kaguya-sama wa Kokurasetai: Ultra RomanticTV
# 9                                           Gintama': EnchousenTV
# 10     Shingeki no Kyojin: The Final Season - Kanketsu-henSpecial
# 11                                        Ginga Eiyuu DensetsuOVA
# 12                   Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV
# 13                                     Fruits Basket: The FinalTV
# 14                                                     Gintama.TV
# 15                                                      GintamaTV
# 16                                            Koe no KatachiMovie
# 17                                   3-gatsu no Lion 2nd SeasonTV
# 18                                         Clannad: After StoryTV
# 19                           Code Geass: Hangyaku no Lelouch R2TV
# 20     Gintama Movie 2: Kanketsu-hen - Yorozuya yo Eien NareMovie
# 21                                   Violet Evergarden MovieMovie
# 22                                   Owarimonogatari 2nd SeasonTV
# 23             Gintama.: Shirogane no Tamashii-hen - Kouhan-senTV
# 24                                                      MonsterTV
# 25                                            Kimi no Na wa.Movie
# 26        Kaguya-sama wa Kokurasetai: First Kiss wa OwaranaiMovie
# 27                                             Bocchi the Rock!TV
# 28                                       The First Slam DunkMovie
# 29                                        Vinland Saga Season 2TV
# 30                                    Jujutsu Kaisen 2nd SeasonTV
# 31                          Gintama.: Shirogane no Tamashii-henTV
# 32                                           Kingdom 3rd SeasonTV
# 33                                            Mob Psycho 100 IITV
# 34                         Shingeki no Kyojin: The Final SeasonTV
# 35                                Kimetsu no Yaiba: Yuukaku-henTV
# 36                          Kizumonogatari III: Reiketsu-henMovie
# 37                                                 "Oshi no Ko"TV
# 38    Haikyuu!! Karasuno Koukou vs. Shiratorizawa Gakuen KoukouTV
# 39                             Sen to Chihiro no KamikakushiMovie
# 40                             Monogatari Series: Second SeasonTV
# 41                  Shingeki no Kyojin: The Final Season Part 2TV
# 42                                               Hajime no IppoTV
# 43                                                 Cowboy BebopTV
# 44                                           Kingdom 4th SeasonTV
# 45                                                 Vinland SagaTV
# 46                                Mushishi Zoku Shou 2nd SeasonTV
# 47         Shouwa Genroku Rakugo Shinjuu: Sukeroku Futatabi-henTV
# 48                                           Mob Psycho 100 IIITV
# 49       Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-henOVA
# Name: Name, dtype: object

# %% [markdown]
# ### Extracting Type

# %%
def extract_type(name):
    if name.endswith("TV "):
        return "TV"
    elif name.endswith("OVA "):
        return "OVA"
    elif name.endswith("Special "):
        return "Special"
    else:
        return "Movie"

# %%
data['Show_Type']=data['Name'].apply(extract_type)

# %%
data.head(5)['Title']
# Out:
# 0       Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview
# 1                                                           Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473,707 members
# 2                                               Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members
# 3                                                                Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 members
# 4    Shingeki no Kyojin Season 3 Part 2TV (10 eps)Apr 2019 - Jul 20192,146,679 membersManga StoreVolume 1€10.99Preview
# Name: Title, dtype: object

# %% [markdown]
# ### Extracting Members

# %%
def extract_members(title):
    tem=""
    for i in range(len(title)):
        while(title[i]!=')'):
            i+=1
        i+=20
        while(title[i]!=' '):
            tem+=title[i]
            i+=1
        break
    mem=tem.replace(',','')
    return mem

# %%
data['Members']=data['Title'].apply(extract_members)

# %% [markdown]
# ### Type Conversion String -> Integer

# %%
data['Members'] = pd.to_numeric(data['Members'], errors='coerce').astype('Int64')

# %%
data.drop('Title',axis=1,inplace=True)

# %%
def remove_clippings(name):
    if name.endswith("TV "):
        return name.replace('TV ','')
    elif name.endswith("OVA "):
        return name.replace('OVA ','')
    elif name.endswith("Special "):
        return name.replace('Special ','')
    else:
        return name.replace('Movie ','')

# %%
data['Name']=data['Name'].apply(remove_clippings)

# %% [markdown]
# ### Reordering Features

# %%
data=data[
    [
        "Score",
        "Rank",
        "months",
        "Members",
        "Episode_Count",
        "Name",
        "start",
        "End",
        "Show_Type"
    ]
]

# %%
data.head(10)
# Out:
#    Score  Rank  months  Members  Episode_Count  \
# 0   9.10     1      15  3218472             64
# 1   9.07     2       5  2473707             24
# 2   9.06     3       2   474138             13
# 3   9.06     4      11   605113             51
# 4   9.05     5       3  2146679             10
# 5   9.04     6      11   534105             51
# 6   9.04     7       0   137208              1
# 7   9.04     8      35  2701154            148
# 8   9.04     9       2   851445             13
# 9   9.03    10       5   313446             13
#
#                                          Name      start        End Show_Type
# 0            Fullmetal Alchemist: Brotherhood  Apr 2009    Jul 2010        TV
# 1                                 Steins;Gate  Apr 2011    Sep 2011        TV
# 2                   Bleach: Sennen Kessen-hen  Oct 2022    Dec 2022        TV
# 3                                    Gintama°  Apr 2015    Mar 2016        TV
# 4          Shingeki no Kyojin Season 3 Part 2  Apr 2019    Jul 2019        TV
# 5                                    Gintama'  Apr 2011    Mar 2012        TV
# 6                          Gintama: The Final  Jan 2021    Jan 2021     Movie
# 7                            Hunter x Hunter   Oct 2011    Sep 2014        TV
# 8  Kaguya-sama wa Kokurasetai: Ultra Romantic  Apr 2022    Jun 2022        TV
# 9                         Gintama': Enchousen  Oct 2012    Mar 2013        TV

# %% [markdown]
# <h1 align="center">***Machine Learning Ready Dataset***</h1>
